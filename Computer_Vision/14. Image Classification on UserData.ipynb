# %%
### Dataset
# fruits.zip

# %%
from keras.models import Sequential
from keras.layers import Dense, Input, Conv2D, MaxPool2D, Flatten, Dropout
from keras.utils import plot_model, to_categorical
from keras.datasets import cifar10
import cv2
import matplotlib.pyplot as plt
import numpy as np
from keras.src.legacy.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Create the object of image data generators

# %%
train_datagen = ImageDataGenerator(rescale = 1/255, zoom_range=0.2,
                                   horizontal_flip = True, vertical_flip = True)

test_datagen = ImageDataGenerator(rescale=1/255)

# %% [markdown]
# ### Read the images

# %%
train = train_datagen.flow_from_directory(
    'D:/NLP_CV/NLP/datasets/fruits/training_set/',
    class_mode='binary', target_size=(64,64)
)
# Out:
# Found 13 images belonging to 2 classes.

# %%
train.filenames
# Out:
# ['apple\\1.jpg',
#  'apple\\2.jpeg',
#  'apple\\3.jpeg',
#  'apple\\4.jpeg',
#  'apple\\5.jpg',
#  'apple\\6.jpg',
#  'apple\\7.jpg',
#  'orange\\1.jpeg',
#  'orange\\2.jpg',
#  'orange\\3.jpeg',
#  'orange\\4.jpeg',
#  'orange\\5.jpg',
#  'orange\\6.jpg']

# %%
train.class_indices
# Out:
# {'apple': 0, 'orange': 1}

# %%
test = test_datagen.flow_from_directory(
    'D:/NLP_CV/NLP/datasets/fruits/test_set/',
    class_mode='binary', target_size=(64,64)
)
# Out:
# Found 6 images belonging to 2 classes.

# %% [markdown]
# ### Build Model

# %%
model = Sequential()

model.add(Input(shape=(64, 64, 3)))

model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())


model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 62, 62, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1568)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        50,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,849 (202.54 KB)
#  Trainable params: 51,849 (202.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(train, validation_data = test, epochs=10, batch_size=1)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.3846 - loss: 0.7138 - val_accuracy: 1.0000 - val_loss: 0.6432
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8462 - loss: 0.6459 - val_accuracy: 1.0000 - val_loss: 0.5827
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9231 - loss: 0.5814 - val_accuracy: 1.0000 - val_loss: 0.5209
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 1.0000 - loss: 0.5093 - val_accuracy: 1.0000 - val_loss: 0.4541
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 1.0000 - loss: 0.4486 - val_accuracy: 1.0000 - val_loss: 0.3875
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 1.0000 - loss: 0.4082 - val_accuracy: 1.0000 - val_loss: 0.3186
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 1.0000 - loss: 0.3189 - val_accuracy: 1.0000 - val_loss: 0.2541
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9231 - loss: 0.2634 - val_accuracy: 1.0000 - val_loss: 0.1973
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 1.0000 - loss: 0.1921 - val_accuracy: 1.0000 - val_loss: 0.1509
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 1.0000 - loss: 0.1795 - val_accuracy: 1.0000 - val_loss: 0.1114

# %% [markdown]
# #### Prediction on New Images

# %%
new1 = plt.imread('D:/NLP_CV/NLP/datasets/fruits/sample1.jpg')
new1 = cv2.resize(new1, (64, 64))
new1 = new1.reshape(1, 64, 64, 3)
result = model.predict(new1, verbose=False)
if result[0][0] == 1:
    print('Orange')
else:
    print('Apple')
# Out:
# Orange

# %%
new1 = plt.imread('D:/NLP_CV/NLP/datasets/fruits/sample2.jpg')
new1 = cv2.resize(new1, (64, 64))
new1 = new1.reshape(1, 64, 64, 3)
result = model.predict(new1, verbose=False)
if result[0][0] == 1:
    print('Orange')
else:
    print('Apple')
# Out:
# Apple
