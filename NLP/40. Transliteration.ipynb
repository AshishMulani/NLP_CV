# %%
pip install indic-transliteration
# Out:
# Collecting indic-transliteration
#   Downloading indic_transliteration-2.3.82-py3-none-any.whl.metadata (1.8 kB)
# Collecting backports.functools_lru_cache (from indic-transliteration)
#   Downloading backports.functools_lru_cache-2.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: regex in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from indic-transliteration) (2026.5.9)
# Requirement already satisfied: typer in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from indic-transliteration) (0.25.1)
# Requirement already satisfied: toml in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from indic-transliteration) (0.10.2)
# Collecting roman (from indic-transliteration)
#   Downloading roman-5.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tqdm in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from indic-transliteration) (4.67.3)
# Requirement already satisfied: colorama in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from tqdm->indic-transliteration) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from typer->indic-transliteration) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from typer->indic-transliteration) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from typer->indic-transliteration) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from typer->indic-transliteration) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from rich>=13.8.0->typer->indic-transliteration) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from rich>=13.8.0->typer->indic-transliteration) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->indic-transliteration) (0.1.2)
# Downloading indic_transliteration-2.3.82-py3-none-any.whl (162 kB)
# Downloading backports.functools_lru_cache-2.0.0-py2.py3-none-any.whl (6.7 kB)
# Downloading roman-5.2-py3-none-any.whl (6.0 kB)
# Installing collected packages: roman, backports.functools_lru_cache, indic-transliteration
#
#    ------------- -------------------------- 1/3 [backports.functools_lru_cache]
#    -------------------------- ------------- 2/3 [indic-transliteration]
#    -------------------------- ------------- 2/3 [indic-transliteration]
#    -------------------------- ------------- 2/3 [indic-transliteration]
#    -------------------------- ------------- 2/3 [indic-transliteration]
#    -------------------------- ------------- 2/3 [indic-transliteration]
#    -------------------------- ------------- 2/3 [indic-transliteration]
#    ---------------------------------------- 3/3 [indic-transliteration]
#
# Successfully installed backports.functools_lru_cache-2.0.0 indic-transliteration-2.3.82 roman-5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

# %%
text = 'Tushar Kute'

# %%
ttext = transliterate(text, sanscript.ITRANS, sanscript.DEVANAGARI)

# %%
ttext
# Out:
# 'टुशर् ख़ुते'
