# %% [markdown]
# ###### • Lexical Analysis and Pattern Matching : Build a custom regular expression script in Python to extract specific entities, such as dates and locations, from a messy text file. Compare the speed and accuracy of this rule-based approach against a pre-trained Named Entity Recognition pipeline in spaCy to understand when to use rules versus machine learning.

# %% [markdown]
# ###### • Morphological Challenges in Regional Languages: 1. Select a short paragraph in English and translate it into a morphologically rich language like Marathi. Run both texts through an open-source tokenization and POS tagging tool, documenting why stemming and tokenization rules that work perfectly for English often struggle with the agglutinative nature of regional languages.

# %% [markdown]
# ###### • Word Sense Disambiguation in Practice: 1. Create a simple script using the Lesk algorithm from the NLTK library to disambiguate polysemous words, such as "bank" or "bat," across different contextual sentences. Analyze the output to identify specific edge cases where the algorithm fails to capture the correct semantic meaning.

# %% [markdown]
# ###### • Building Domain-Specific Ontologies: 1. Utilize a no-code or low-code graphical ontology editor, such as WebProtégé, to design a small knowledge graph for a specific domain like an educational institution. Write a basic script to parse university website text and map the extracted entities to the relationships defined in your custom ontology.

# %% [markdown]
# ###### • Traditional Machine Learning versus Zero-Shot Classification: 1. Train a basic Naive Bayes or Support Vector Machine classifier for text categorization using a standard movie review dataset. Process the exact same dataset using a zero-shot classification pipeline from Hugging Face, comparing the traditional model's training time against the transformer's out-of-the-box performance and interpretability.

# %%
• Traditional Machine Learning versus Zero-Shot Classification:
1. Train a basic Naive Bayes or Support Vector Machine classifier for text
categorization using a standard movie review dataset. Process the exact
same dataset using a zero-shot classification pipeline from Hugging Face,
comparing the traditional model's training time against the transformer's
out-of-the-box performance and interpretability.

# %%
• Visualizing Transformer Self-Attention:
1. Access a free online visualization tool for transformer architectures, such as
BertViz. Input a complex sentence containing ambiguous pronouns and
trace the self-attention weights across different layers to observe exactly
which surrounding words the model focuses on to resolve the syntactic
ambiguity.

# %%
• Rapid Low-Code Model Deployment:
1. Construct a lightweight web application for text summarization or
sentiment analysis by wrapping a Hugging Face pipeline in a Gradio or
Streamlit interface. This exercise demonstrates how to quickly make
complex NLP models accessible and interactive for non-technical end users
without writing extensive backend code.

# %%
• Multilingual and Historical Text Translation:
1. Compare the performance of a commercial translation API against an
open-source, localized language model, such as those provided by IndicNLP
or Bhashini. Use an excerpt from a historical biography or domain-specific
text and analyze the differences in how each model preserves historical
context and cultural nuance.

# %%
• Acoustic Challenges in Speech Processing:
1. Record multiple short audio clips of the same sentence, varying the
background noise levels and speaking styles. Process these recordings
through an open-source speech-to-text system like OpenAI's Whisper,
calculating the Word Error Rate for each transcription to understand the
practical limitations of acoustic models in real-world environments.
