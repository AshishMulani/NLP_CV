# %%
pip install nltk spacy textblob -U
# Out:
# Requirement already satisfied: nltk in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (3.9.4)
# Requirement already satisfied: spacy in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (3.8.14)
# Requirement already satisfied: textblob in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (0.20.0)
# Requirement already satisfied: click in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (0.26.2)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (2.33.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: typing_extensions<5.0,>=4.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from confection<2.0.0,>=1.3.2->spacy) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.4.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pgcp-ai\.conda\envs\dnn_ai_26\lib\site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab') #tokenization
nltk.download('stopwords') 
nltk.download('averaged_perceptron_tagger') #POS tagging
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet') #wordnet and lemmatization
nltk.download('indian') #INDIAN POS tagging
nltk.download('omw-1.4') #multilinguial wordnet
# Out:
# [nltk_data] Downloading package punkt to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\PGCP-AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\PGCP-AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package wordnet to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package indian to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\indian.zip.
# [nltk_data] Downloading package omw-1.4 to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# True

# %%
# Out:
# [24, 31, 29]
