# %%
sent = 'They told that their ages are 24 31 and 29 respectively'
# Find the avg of ages
words_sent = sent.split()
ages = []

for i in words_sent:
    if i.isdigit():
      ages.append(int(i))  

print("Ages", ages)
print("Average",sum(ages)/len(ages))
# Out:
# Ages [24, 31, 29]
# Average 28.0

# %%
ages = [int(word) for word in sent.split() if word.isdigit()]
ages
# Out:
# [24, 31, 29]

# %% [markdown]
# # Tokenizers and Types

# %% [markdown]
# ## 1. Word and Sentence Tokenizer

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sent ='''Hello friends!
How are you?
Welcome to the world of Python Programming.'''
print(sent)
# Out:
# Hello friends!
# How are you?
# Welcome to the world of Python Programming.

# %%
sents = sent_tokenize(sent)
sents
# Out:
# ['Hello friends!',
#  'How are you?',
#  'Welcome to the world of Python Programming.']

# %%
sents[0]
# Out:
# 'Hello friends!'

# %%
sents[1][11]
# Out:
# '?'

# %%
sents[2]
# Out:
# 'Welcome to the world of Python Programming.'

# %%
n = len(sents)
n
# Out:
# 3

# %%
words = word_tokenize(sent)
words
# Out:
# ['Hello',
#  'friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming',
#  '.']

# %%
words[5]
# Out:
# 'you'

# %%
n = len(words)
n
# Out:
# 15

# %%
# Among all the tokens, find percentage of punctuation symbols in it

import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
lst = []
for word in words :
    if word in string.punctuation :
      lst.append(word)
print(lst)
print(len(lst)/len(words)*100,'%')
# Out:
# ['!', '?', '.']
# 20.0 %

# %%
sent
# Out:
# 'Hello friends!\nHow are you?\nWelcome to the world of Python Programming.'

# %%
lst = []
for word in words :
    if word not in string.punctuation :
      lst.append(word)
print(lst)
# Out:
# ['Hello', 'friends', 'How', 'are', 'you', 'Welcome', 'to', 'the', 'world', 'of', 'Python', 'Programming']

# %%
new_str = ''
for char in sent :
  if char not in string.punctuation:
    new_str += char
print(new_str)
# Out:
# Hello friends
# How are you
# Welcome to the world of Python Programming

# %%
str1 = '''पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]

पुण्यावर राष्ट्रकूट राजघराणे, अहमदनगर सल्तनत, मुघल, आदिल शाही घराणे यांनी राज्य केले आहे. १८ व्या शतकात हे शहर मराठा साम्राज्याचा भाग होते, आणि मराठा साम्राज्याचे पंतप्रधान, पेशव्यांची हे आसन होते.[१८] पाताळेश्वर लेणी, शनिवारवाडा, शिंदे छत्री, विश्रामबाग वाडा यासारख्या अनेक ऐतिहासिक खुणा या कालखंडातील आहेत. वेगवेगळ्या कालखंडातील ऐतिहासिक स्थळे शहरभर पसरलेली आहेत.'''

# %%
print(str1)
# Out:
# पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]
#
# पुण्यावर राष्ट्रकूट राजघराणे, अहमदनगर सल्तनत, मुघल, आदिल शाही घराणे यांनी राज्य केले आहे. १८ व्या शतकात हे शहर मराठा साम्राज्याचा भाग होते, आणि मराठा साम्राज्याचे पंतप्रधान, पेशव्यांची हे आसन होते.[१८] पाताळेश्वर लेणी, शनिवारवाडा, शिंदे छत्री, विश्रामबाग वाडा यासारख्या अनेक ऐतिहासिक खुणा या कालखंडातील आहेत. वेगवेगळ्या कालखंडातील ऐतिहासिक स्थळे शहरभर पसरलेली आहेत.

# %%
word_tokenize(str1)
# Out:
# ['पुणे',
#  'हे',
#  'भारताच्या',
#  'दख्खन',
#  'पठारावरील',
#  'महाराष्ट्राचे',
#  'एक',
#  'महत्त्वाचे',
#  'शहर',
#  'आहे',
#  '.',
#  'पुणे',
#  'जिल्ह्याचे',
#  'आणि',
#  'पुणे',
#  'विभागाचे',
#  'हे',
#  'प्रशासकीय',
#  'मुख्यालय',
#  'आहे',
#  '.',
#  '२०११',
#  'जनगणनेनुसार',
#  ',',
#  'शहराच्या',
#  'हद्दीतील',
#  '३.१',
#  'दशलक्ष',
#  'लोकसंख्येसह',
#  'पुणे',
#  'हे',
#  'भारतातील',
#  'नववे',
#  'सर्वात',
#  'जास्त',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  'महानगर',
#  'प्रदेशातील',
#  '७.२',
#  'दशलक्ष',
#  'रहिवासी',
#  'लोकसंख्या',
#  'आहे',
#  ',',
#  'यानुसार',
#  'ते',
#  'आठवे',
#  'सर्वाधिक',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  '[',
#  '८',
#  ']',
#  'पुणे',
#  'शहर',
#  'पुणे',
#  'महानगर',
#  'प्रदेशाचा',
#  'एक',
#  'भाग',
#  'आहे',
#  '.',
#  '[',
#  '९',
#  ']',
#  'भारतातील',
#  'सर्वात',
#  'मोठ्या',
#  'आयटी',
#  'हबपैकी',
#  'पुणे',
#  'एक',
#  'आहे',
#  '.',
#  '[',
#  '१०',
#  ']',
#  '[',
#  '११',
#  ']',
#  'हे',
#  'भारतातील',
#  'सर्वात',
#  'महत्वाचे',
#  'ऑटोमोबाईल',
#  'आणि',
#  'उत्पादन',
#  'केंद्रांपैकी',
#  'एक',
#  'आहे',
#  '.',
#  'पुणे',
#  'हे',
#  'एक',
#  'विकसनशील',
#  'शहर',
#  'आहे',
#  '.',
#  '[',
#  '१२',
#  ']',
#  'या',
#  'शहराला',
#  'येथील',
#  'उच्च',
#  'प्रतिष्ठित',
#  'शैक्षणिक',
#  'संस्थांमुळे',
#  '``',
#  'पूर्वेकडील',
#  'ऑक्सफर्ड',
#  "''",
#  'म्हणून',
#  'संबोधले',
#  'जाते',
#  '.',
#  '[',
#  '१३',
#  ']',
#  '[',
#  '१४',
#  ']',
#  '[',
#  '१५',
#  ']',
#  '``',
#  'भारतातील',
#  'सर्वात',
#  'राहण्यायोग्य',
#  'शहर',
#  "''",
#  'म्हणून',
#  'अनेक',
#  'वेळा',
#  'पुण्याला',
#  'स्थान',
#  'देण्यात',
#  'आले',
#  'आहे',
#  '.',
#  '[',
#  '१६',
#  ']',
#  '[',
#  '१७',
#  ']',
#  'पुण्यावर',
#  'राष्ट्रकूट',
#  'राजघराणे',
#  ',',
#  'अहमदनगर',
#  'सल्तनत',
#  ',',
#  'मुघल',
#  ',',
#  'आदिल',
#  'शाही',
#  'घराणे',
#  'यांनी',
#  'राज्य',
#  'केले',
#  'आहे',
#  '.',
#  '१८',
#  'व्या',
#  'शतकात',
#  'हे',
#  'शहर',
#  'मराठा',
#  'साम्राज्याचा',
#  'भाग',
#  'होते',
#  ',',
#  'आणि',
#  'मराठा',
#  'साम्राज्याचे',
#  'पंतप्रधान',
#  ',',
#  'पेशव्यांची',
#  'हे',
#  'आसन',
#  'होते',
#  '.',
#  '[',
#  '१८',
#  ']',
#  'पाताळेश्वर',
#  'लेणी',
#  ',',
#  'शनिवारवाडा',
#  ',',
#  'शिंदे',
#  'छत्री',
#  ',',
#  'विश्रामबाग',
#  'वाडा',
#  'यासारख्या',
#  'अनेक',
#  'ऐतिहासिक',
#  'खुणा',
#  'या',
#  'कालखंडातील',
#  'आहेत',
#  '.',
#  'वेगवेगळ्या',
#  'कालखंडातील',
#  'ऐतिहासिक',
#  'स्थळे',
#  'शहरभर',
#  'पसरलेली',
#  'आहेत',
#  '.']

# %%
new_sent = 'Dr. Mrs. Kulkarni got ₹ 12 lakh salary.'
word_tokenize(new_sent)
# Out:
# ['Dr.', 'Mrs.', 'Kulkarni', 'got', '₹', '12', 'lakh', 'salary', '.']

# %% [markdown]
# ### Load the file mydata.txt and find avg of numbers in it.

# %%
# Load file

f = open('mydata.txt')
data = f.read()
data
# Out:
# '12 abcd 15, 10\n4, 9, 9, and 12 10\n4.5, 11, 6.3 xyz\n\n'

# %%
data = word_tokenize(data)
nums = []
for word in data:
    if not word.isalpha() and word not in string.punctuation:
        nums.append(float(word))
sum(nums)/len(nums)
# Out:
# 9.345454545454546

# %%
nums
# Out:
# [12.0, 15.0, 10.0, 4.0, 9.0, 9.0, 12.0, 10.0, 4.5, 11.0, 6.3]

# %% [markdown]
# ## 2. White Space Tokenizer

# %%
from nltk.tokenize import WhitespaceTokenizer
tk = WhitespaceTokenizer()
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming.']

# %% [markdown]
# ### 2.1. Space Tokenizer

# %%
from nltk.tokenize import SpaceTokenizer
tk = SpaceTokenizer()
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?\nWelcome\tto',
#  'the',
#  'world',
#  'of',
#  'Python\tProgramming.']

# %% [markdown]
# ### 2.2. Tab Tokenizer

# %%
sent = '''Hello friends! How are you?
Welcome\tto the world of Python\tProgramming.'''
print(sent)
# Out:
# Hello friends! How are you?
# Welcome	to the world of Python	Programming.

# %%
from nltk.tokenize import TabTokenizer
tk = TabTokenizer()
tk.tokenize(sent)
# Out:
# ['Hello friends! How are you?\nWelcome',
#  'to the world of Python',
#  'Programming.']

# %%
sent.split('\t')
# Out:
# ['Hello friends! How are you?\nWelcome',
#  'to the world of Python',
#  'Programming.']

# %% [markdown]
# ### 2.3. Line Tokenizer

# %%
from nltk.tokenize import LineTokenizer
tk = LineTokenizer()
tk.tokenize(sent)
# Out:
# ['Hello friends! How are you?',
#  'Welcome\tto the world of Python\tProgramming.']

# %% [markdown]
# ## 3. Multi Word Expression Tokenizer

# %%
from nltk.tokenize import MWETokenizer

# %%
nsent = 'Chhatrapati Shivaji Maharaj was founder of Maratha Empire'
word_tokenize(nsent)
# Out:
# ['Chhatrapati',
#  'Shivaji',
#  'Maharaj',
#  'was',
#  'founder',
#  'of',
#  'Maratha',
#  'Empire']

# %%
mwe = MWETokenizer(separator=' ')
mwe.add_mwe(('Chhatrapati','Shivaji'))
mwe.tokenize(word_tokenize(nsent))
# Out:
# ['Chhatrapati Shivaji', 'Maharaj', 'was', 'founder', 'of', 'Maratha', 'Empire']

# %% [markdown]
# ## 4. Tweet Tokenizer

# %%
sent ='Hello friends 🙌  How are you...🫂 Welcome to the world of Python Programming.🦾'

# %%
from nltk.tokenize import TweetTokenizer
tk = TweetTokenizer()
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends',
#  '🙌',
#  'How',
#  'are',
#  'you',
#  '...',
#  '🫂',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming',
#  '.',
#  '🦾']

# %%
text = '😍'
text
# Out:
# '😍'

# %%
sent ='Hello friends 🙌  How are you...🫂 Welcome to the world of Python Programming.🦾'
sent
# Out:
# 'Hello friends 🙌  How are you...🫂 Welcome to the world of Python Programming.🦾'

# %% [markdown]
# ### 4.1. UNICODE

# %%
name ='आशिष मुलाणी शेठ... ईद मुबारक!'
name
# Out:
# 'आशिष मुलाणी शेठ... ईद मुबारक!'

# %%
name.replace('शेठ','साहेब')
# Out:
# 'आशिष मुलाणी साहेब... ईद मुबारक!'

# %%
name.startswith('आ')
# Out:
# True

# %%
name.split()
# Out:
# ['आशिष', 'मुलाणी', 'शेठ...', 'ईद', 'मुबारक!']

# %%
name.isascii()  # becoz it's UNICODE
# Out:
# False

# %%
name.index('मु')
# Out:
# 5

# %%
name.index(' ')
# Out:
# 4

# %%
name.index('म')
# Out:
# 5

# %%
len(name)
# Out:
# 29

# %%
char = '\u0915\u0901'
char
# Out:
# 'कँ'

# %%
char = "\u0915\u093E"
char
# Out:
# 'का'

# %%
char = "\u0041\u0073"
char
# Out:
# 'As'

# %%
ord('क')
# Out:
# 2325

# %%
chr(2354)
# Out:
# 'ल'

# %% [markdown]
# ## 5. Custom Tokenizer

# %%
import re
def custom_tokenizer(text):
    return re.split(r"[.,;?!\s]+", text)
text = "This is some text with punctuation > Let's tokenize it. Is it ok?"
custom_tokenizer(text)
# Out:
# ['This',
#  'is',
#  'some',
#  'text',
#  'with',
#  'punctuation',
#  '>',
#  "Let's",
#  'tokenize',
#  'it',
#  'Is',
#  'it',
#  'ok',
#  '']

# %%
class CommaTokenizer:
    def tokeinze (self,text):
         return re.split(r"[,\s]+", text)
tk = CommaTokenizer()   
fruits = 'apple, banana, cherry, pineapple.'
tk.tokeinze(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple.']
